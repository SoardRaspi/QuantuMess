# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os 
for dirname, _, filenames in os.walk('train'):
    for filename in filenames:
        # print(os.path.join(dirname, filename))
        pass

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import tensorflow as tf
import pandas as pd
import numpy as np

from tensorflow import keras
from keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from tensorflow.keras.preprocessing import image_dataset_from_directory

import torch
import torch.nn as nn
import torch.nn.functional as F

import pennylane as qml

import os

# %%
base_path = "train"

# %% [markdown]
# **Test Image display**

# %%
image = mpimg.imread(os.path.join(base_path, "2/170913-143933-Al 2mm-part2_frame_00562.png"))

plt.imshow(image)
plt.show()

# %%
image.shape
# Out:
# (128, 128)

# %% [markdown]
# **Main Code starting now**

# %% [markdown]
# Parameters

# %%
# num_quantum_features = 8
# num_layers = 4

num_quantum_features = 4
num_layers = 3

dev = qml.device("default.qubit", wires=num_quantum_features)

# %%
def layer(weights_0, weights_1, num_qubits):
    # Adding the Rot gates and the CNOT gates
    for wire in range(num_qubits):
        qml.Rot(*weights_0[wire], wires=wire)

    for wire in range(num_qubits):
        qml.CNOT([wire, (wire+1)%num_qubits])

    # Adding the SEL part
    if weights_1 is not None:
        for wire in range(num_qubits):
            y_val, z_val, x_val = weights_1[wire]
    
            qml.RY(y_val, wires=wire)
            qml.RZ(z_val, wires=wire)
            qml.RX(x_val, wires=wire)

# %%
## shape of weights = (num_layers x ([[rot...], [Wp...]]))

@qml.qnode(dev)
def qnode(inputs, encoding, weights_0, weights_1):
    # print("lenght of inputs:", len(inputs))
    # print("lenght of encoding:", encoding.shape)
    # print("lenght of weights_0:", weights_0.shape)
    # print("lenght of weights_1:", weights_1.shape)
    
    n_qubits = num_quantum_features
    n_layers = len(weights_0)-1
    
    for layer_num in range(n_layers):
        layer(weights_0[layer_num], weights_1[layer_num], n_qubits)

        for wire in range(n_qubits):
            qml.RZ((2**layer_num)*encoding[wire], wires=wire)

    layer(weights_0[n_layers], None, n_qubits)
    return [qml.expval(qml.Z(i)) for i in range(n_qubits)]

# %%
weight_shapes = {"encoding": (num_quantum_features, 1), "weights_0": (num_layers, num_quantum_features, 3), "weights_1": (num_layers - 1, num_quantum_features, 3)}
qlayer = qml.qnn.TorchLayer(qnode, weight_shapes)

# %% [markdown]
# **Your Normal Classical PyTorch Model**

# %%
# # # Using it in one model

# # class PHN(nn.Module):
# #     def __init__(self, qlayer):
# #         super(PHN, self).__init__()

# #         # # For image of shape (3, 128, 128)
# #         # self.conv1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3)
# #         # self.conv2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3)
# #         # self.conv3 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3)
# #         # self.conv4 = nn.Conv2d(in_channels=128, out_channels=64, kernel_size=3)
# #         # self.conv5 = nn.Conv2d(in_channels=64, out_channels=32, kernel_size=3)

# #         # For image of shape (3, 180, 180)
# #         self.conv1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=7)
# #         self.conv2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=5)
# #         self.conv3 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3)
# #         self.conv4 = nn.Conv2d(in_channels=128, out_channels=64, kernel_size=3)
# #         self.conv5 = nn.Conv2d(in_channels=64, out_channels=32, kernel_size=5)
        
# #         self.dense1 = nn.Linear(128, 64)
# #         self.bn1 = nn.BatchNorm1d(64)
        
# #         self.dense2 = nn.Linear(64, 32)
# #         self.bn2 = nn.BatchNorm1d(32)
        
# #         self.dense3 = nn.Linear(32, 8)
# #         self.bn3 = nn.BatchNorm1d(8)
        
# #         self.pool = nn.MaxPool2d(2, 2)
# #         self.d1 = nn.Dropout(0.2)
        
# #         # Following is for the parallel part
        
# #         self.dense4 = nn.Linear(8, 16)
# #         self.bn4 = nn.BatchNorm1d(16)
# #         self.ln4 = nn.LayerNorm(16)
        
# #         self.dense5 = nn.Linear(16, 32)
# #         self.bn5 = nn.BatchNorm1d(32)
# #         self.ln5 = nn.LayerNorm(32)
        
# #         self.dense6 = nn.Linear(32, 32)
# #         self.bn6 = nn.BatchNorm1d(32)
# #         self.ln6 = nn.LayerNorm(32)
        
# #         self.dense7 = nn.Linear(32, 16)
# #         self.bn7 = nn.BatchNorm1d(16)
# #         self.ln7 = nn.LayerNorm(16)
        
# #         self.dense8 = nn.Linear(16, 8)
# #         self.bn8 = nn.BatchNorm1d(8)
# #         self.ln8 = nn.LayerNorm(8)

# #         self.dense_x_para = nn.Linear(16, 8)
        
# #         # After the parallel part
        
# #         self.merge_layer = nn.Linear(16, 8)
# #         # self.merge_layer = nn.Linear(8, 8)
        
# #         self.bn_merge_layer = nn.BatchNorm1d(8)
# #         self.ln_merge_layer = nn.LayerNorm(8)
        
# #         self.densef = nn.Linear(8, 6)

# #         self.qlayer = qlayer

# #         self.softmax = nn.Softmax(dim=1)

# #     def forward(self, x):
# #         x = F.relu(self.conv1(x))
# #         x = self.pool(x)
# #         x = F.relu(self.conv2(x))
# #         x = self.pool(x)
# #         x = F.relu(self.conv3(x))
# #         x = self.pool(x)
# #         x = F.relu(self.conv4(x))
# #         x = self.pool(x)
# #         x = F.relu(self.conv5(x))
# #         x = self.pool(x)

# #         # x = x.view(-1, 32 * 3 * 3)
# #         x = nn.Flatten()(x)
# #         # print("shape of tensor after flatten:", x.shape)

# #         x = F.relu(self.dense1(x))
# #         # print("shape of tensor after dense1:", x.shape)
# #         x = self.d1(x)
# #         # print("shape of tensor after dropout:", x.shape)
# #         x = self.bn1(x)
# #         # print("shape of tensor after bn1:", x.shape)
# #         x = F.relu(self.dense2(x))
# #         x = self.d1(x)
# #         x = self.bn2(x)
# #         x = F.relu(self.dense3(x))
# #         x = self.d1(x)
# #         x_para = self.bn3(x)
# #         print("x_para:", x_para)
# #         print("x_para shape:", x_para.shape)

# #         # Comment/Uncomment the following lines for Hybrid Quantum Thing

# #         # x_para_ = x_para.view(1, -1)
# #         # print("x_para after flatten:", x_para_)
# #         # print("x_para after flatten shape:", x_para_.shape)
# #         # x_para_ = F.relu(self.dense_x_para(x_para_))
# #         # x_para_ = self.d1(x_para_)

# #         x_para_ = x_para
# #         print("shape of x_para_:", x_para_.shape)
        
# #         x_para_sig_ = torch.sigmoid(x_para_)
# #         print("x_para_sig_:", x_para_sig_)
# #         print("x_para_sig_ shape:", x_para_sig_.shape)
        
# #         x_para_sig_quantum, x_para_sig_classical = torch.split(x, 1, dim=0)

# #         print("x_para_sig_quantum shape:", x_para_sig_quantum.shape)
# #         # x_para_sig_q_ = self.qlayer(x_para_sig_)
# #         x_para_sig_q_ = self.qlayer(x_para_sig_quantum)
# #         print("x_para_sig_q_ shape:", x_para_sig_q_.shape)

# #         print("x_para_sig_classical shape:", x_para_sig_classical.shape)
# #         # x = F.relu(self.dense4(x_para_sig_))
# #         x = F.relu(self.dense4(x_para_sig_classical))
# #         print("Shape of x after dense4:", x.shape)
# #         x = self.d1(x)
# #         print("Shape of x after dense4 d1:", x.shape)
# #         # x = self.bn4(x)
# #         # print("Shape of x after dense4 d1 bn4:", x.shape)
# #         x = self.ln4(x)
# #         print("Shape of x after dense4 d1 ln4:", x.shape)
        
# #         x = F.relu(self.dense5(x))
# #         x = self.d1(x)
# #         # x = self.bn5(x)
# #         x = self.ln5(x)
        
# #         x = F.relu(self.dense6(x))
# #         x = self.d1(x)
# #         # x = self.bn6(x)
# #         x = self.ln6(x)
        
# #         x = F.relu(self.dense7(x))
# #         x = self.d1(x)
# #         # x = self.bn7(x)
# #         x = self.ln7(x)
        
# #         x = F.relu(self.dense8(x))
# #         x = self.d1(x)
# #         # x = self.bn8(x)
# #         x = self.ln8(x)

# #         # # Comment/Uncomment the following lines for Hybrid Quantum Thing
# #         x_para_sig = torch.sigmoid(x)
# #         print("shape of x_para_sig at concat:", x_para_sig.shape, x_para_sig_q_.shape)
        
# #         # x = torch.cat((x_para_sig, x_para_sig_q), dim=1)
# #         x = torch.cat((x_para_sig, x_para_sig_q_), dim=1)
# #         print("shape of x after concat:", x.shape)

# #         x = F.relu(self.merge_layer(x))
# #         x = self.d1(x)
# #         # x = self.bn_merge_layer(x)
# #         x = self.ln_merge_layer(x)

# #         x = self.densef(x)
# #         x = self.softmax(x)

# #         return x

# class PHN(nn.Module):
#     def __init__(self, qlayer):
#         super(PHN, self).__init__()

#         # # Convolutional layers for input shape (3, 180, 180)
#         # self.conv1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=7)
#         # self.conv2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=5)
#         # self.conv3 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3)
#         # self.conv4 = nn.Conv2d(in_channels=128, out_channels=64, kernel_size=3)
#         # self.conv5 = nn.Conv2d(in_channels=64, out_channels=32, kernel_size=5)

#         # Convolutional layers for input shape (3, 180, 180) but lighter (upper one takes forever to train)
#         self.conv1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=7)
#         self.conv2 = nn.Conv2d(in_channels=32, out_channels=16, kernel_size=5)
#         self.conv3 = nn.Conv2d(in_channels=16, out_channels=8, kernel_size=3)
#         self.conv4 = nn.Conv2d(in_channels=8, out_channels=16, kernel_size=3)
#         self.conv5 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=5)

#         self.pool = nn.MaxPool2d(2, 2)
#         self.d1 = nn.Dropout(0.2)

#         # Fully connected layers
#         self.dense1 = nn.Linear(32 * 2 * 2, 64)  # Adjust input size after flattening
#         self.bn1 = nn.BatchNorm1d(64)
        
#         self.dense2 = nn.Linear(64, 32)
#         self.bn2 = nn.BatchNorm1d(32)
        
#         self.dense3 = nn.Linear(32, 16)
#         self.bn3 = nn.BatchNorm1d(16)

#         # Layers for parallel processing part
#         self.dense4 = nn.Linear(8, 16)
#         self.bn4 = nn.BatchNorm1d(16)
#         self.ln4 = nn.LayerNorm(16)
        
#         self.dense5 = nn.Linear(16, 32)
#         self.bn5 = nn.BatchNorm1d(32)
#         self.ln5 = nn.LayerNorm(32)
        
#         self.dense6 = nn.Linear(32, 32)
#         self.bn6 = nn.BatchNorm1d(32)
#         self.ln6 = nn.LayerNorm(32)
        
#         self.dense7 = nn.Linear(32, 16)
#         self.bn7 = nn.BatchNorm1d(16)
#         self.ln7 = nn.LayerNorm(16)
        
#         self.dense8 = nn.Linear(16, 8)
#         self.bn8 = nn.BatchNorm1d(8)
#         self.ln8 = nn.LayerNorm(8)

#         self.dense_x_para = nn.Linear(16, 8)
        
#         # Merging layers after parallel processing
#         # self.merge_layer = nn.Linear(16, 8)
#         self.merge_layer = nn.Linear(12, 8)
        
#         self.bn_merge_layer = nn.BatchNorm1d(8)
#         self.ln_merge_layer = nn.LayerNorm(8)

#         # Final output layer
#         self.densef = nn.Linear(8, 6)
        
#         # Quantum layer placeholder
#         self.qlayer = qlayer

#         self.softmax = nn.Softmax(dim=1)

#     def forward(self, x):
#         # Convolutional layers with pooling
#         # print("x shape 1:", x.shape)
        
#         x = F.relu(self.conv1(x))
#         # print("x shape 2.1:", x.shape)
#         x = self.pool(x)
#         # print("x shape 2.2:", x.shape)
#         x = F.relu(self.conv2(x))
#         # print("x shape 2.3:", x.shape)
#         x = self.pool(x)
#         # print("x shape 2.4:", x.shape)
#         x = F.relu(self.conv3(x))
#         # print("x shape 3:", x.shape)
#         x = self.pool(x)
#         # print("x shape 3.1:", x.shape)
#         x = F.relu(self.conv4(x))
#         # print("x shape 3.2:", x.shape)
#         x = self.pool(x)
#         # print("x shape 3.3:", x.shape)
#         x = F.relu(self.conv5(x))
#         # print("x shape 4.1:", x.shape)
#         x = self.pool(x)
#         # print("x shape 4.2:", x.shape)

#         # Flatten for fully connected layers
#         x = x.view(x.size(0), -1)
#         # print("x shape flatten:", x.shape)

#         # Dense layers with BatchNorm and Dropout
#         x = F.relu(self.dense1(x))
#         # print("x shape dense 1:", x.shape)
#         x = self.d1(x)
#         # print("x shape dense 1 d1:", x.shape)
#         x = self.bn1(x)
#         # print("x shape bn1:", x.shape)
        
#         x = F.relu(self.dense2(x))
#         # print("x shape dense 2:", x.shape)
#         x = self.d1(x)
#         # print("x shape dense 2 d1:", x.shape)
#         x = self.bn2(x)
#         # print("x shape bn2:", x.shape)
        
#         x = F.relu(self.dense3(x))
#         # print("x shape dense 3:", x.shape)
#         x = self.d1(x)
#         # print("x shape dense 3 d1:", x.shape)
#         x_para = self.bn3(x)
#         # print("x shape bn3:", x_para.shape, type(x_para))

#         # Parallel processing part
#         x_para_sig_ = torch.sigmoid(x_para)
#         # print("x shape x_para_sig_:", x_para_sig_.shape)
#         x_para_sig_quantum, x_para_sig_classical = torch.split(x_para_sig_, 8, dim=-1)
#         # print("x shape, x_para_sig_quantum, x_para_sig_classical:", x_para_sig_quantum.shape, 
#               # x_para_sig_classical.shape)

#         # Quantum layer processing
#         x_para_sig_q_ = []
#         for i in range(x_para_sig_quantum.shape[0]):
#             x_para_sig_q_item_temp = self.qlayer(x_para_sig_quantum[i])
#             x_para_sig_q_.append(x_para_sig_q_item_temp)
        
#         x_para_sig_q_ = torch.stack(x_para_sig_q_)
        
#         # x_para_sig_q_ = self.qlayer(x_para_sig_quantum[0])
#         # x_para_sig_q_ = x_para_sig_quantum
        
#         # print("type of x_para_sig_q_ and type of element also", type(x_para_sig_q_), type(x_para_sig_q_[0]))
#         # print("x shape x_para_sig_q_:", x_para_sig_q_.shape)

#         # Classical processing
#         x = F.relu(self.dense4(x_para_sig_classical))
#         # print("x shape dense 4:", x.shape)
#         x = self.d1(x)
#         # print("x shape dense 4 d1:", x.shape)
#         x = self.ln4(x)
#         # print("x shape ln4:", x.shape)
        
#         # x = F.relu(self.dense5(x))
#         # # print("x shape dense 5:", x.shape)
#         # x = self.d1(x)
#         # # print("x shape dense 5 d1:", x.shape)
#         # x = self.ln5(x)
#         # # print("x shape ln5:", x.shape)
        
#         # # x = F.relu(self.dense6(x))
#         # # # print("x shape dense 6:", x.shape)
#         # # x = self.d1(x)
#         # # # print("x shape dense 6 d1:", x.shape)
#         # # x = self.ln6(x)
#         # # # print("x shape ln6:", x.shape)
        
#         # x = F.relu(self.dense7(x))
#         # # print("x shape dense 7:", x.shape)
#         # x = self.d1(x)
#         # # print("x shape dense 7 d1:", x.shape)
#         # x = self.ln7(x)
#         # # print("x shape ln7:", x.shape)
        
#         x = F.relu(self.dense8(x))
#         # print("x shape  dense 8:", x.shape)
#         x = self.d1(x)
#         # print("x shape  dense 8 d1:", x.shape)
#         x = self.ln8(x)
#         # print("x shape ln8:", x.shape)

#         # Concatenate quantum and classical results
#         x = torch.cat((x, x_para_sig_q_), dim=1)
#         # print("x shape concat:", x.shape)

#         # Merge layer with normalization
#         x = F.relu(self.merge_layer(x))
#         # print("x shape merge_layer:", x.shape)
#         x = self.d1(x)
#         # print("x shape merge_layer d1:", x.shape)
#         x = self.ln_merge_layer(x)
#         # print("x shape ln_merge_layer:", x.shape)

#         # Final classification layer
#         x = self.densef(x)
#         # print("x shape densef:", x.shape)
#         x = self.softmax(x)
#         print("x shape final:", x.shape)

#         return x

class PHN(nn.Module):
    def __init__(self, qlayer):
        super(PHN, self).__init__()

        self.flatten = nn.Flatten()
        self.d1 = nn.Dropout(0.2)

        self.dense1 = nn.Linear(3 * 128 * 128, 64)  # Flattened image input
        self.bn1 = nn.BatchNorm1d(64)
        
        self.dense2 = nn.Linear(64, 32)
        self.bn2 = nn.BatchNorm1d(32)
        
        self.dense3 = nn.Linear(32, 16)
        self.bn3 = nn.BatchNorm1d(16)

        self.dense4 = nn.Linear(8, 16)
        self.bn4 = nn.BatchNorm1d(16)
        self.ln4 = nn.LayerNorm(16)
        
        self.dense5 = nn.Linear(16, 32)
        self.bn5 = nn.BatchNorm1d(32)
        self.ln5 = nn.LayerNorm(32)
        
        self.dense6 = nn.Linear(32, 32)
        self.bn6 = nn.BatchNorm1d(32)
        self.ln6 = nn.LayerNorm(32)
        
        self.dense7 = nn.Linear(32, 16)
        self.bn7 = nn.BatchNorm1d(16)
        self.ln7 = nn.LayerNorm(16)
        
        self.dense8 = nn.Linear(16, 8)
        self.bn8 = nn.BatchNorm1d(8)
        self.ln8 = nn.LayerNorm(8)

        self.dense_x_para = nn.Linear(16, 8)
        
        self.merge_layer = nn.Linear(12, 8)
        
        self.bn_merge_layer = nn.BatchNorm1d(8)
        self.ln_merge_layer = nn.LayerNorm(8)

        self.densef = nn.Linear(8, 6)
        
        self.qlayer = qlayer

        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = self.flatten(x)

        x = F.relu(self.dense1(x))
        x = self.d1(x)
        x = self.bn1(x)
        
        x = F.relu(self.dense2(x))
        x = self.d1(x)
        x = self.bn2(x)
        
        x = F.relu(self.dense3(x))
        x = self.d1(x)
        x = self.bn3(x)
        x_para = x

        x_para_sig_ = torch.sigmoid(x_para)

        x_para_sig_quantum, x_para_sig_classical = torch.split(x_para_sig_, 8, dim=-1)

        x_para_sig_q_ = []
        for i in range(x_para_sig_quantum.shape[0]):
            x_para_sig_q_item_temp = self.qlayer(x_para_sig_quantum[i])
            x_para_sig_q_.append(x_para_sig_q_item_temp)
        
        x_para_sig_q_ = torch.stack(x_para_sig_q_)

        x = F.relu(self.dense4(x_para_sig_classical))
        x = self.d1(x)
        x = self.ln4(x)

        x = F.relu(self.dense8(x))
        x = self.d1(x)
        x = self.ln8(x)

        x = torch.cat((x, x_para_sig_q_), dim=1)

        x = F.relu(self.merge_layer(x))
        x = self.d1(x)
        x = self.ln_merge_layer(x)

        x = self.densef(x)
        x = self.softmax(x)

        return x

# %% [markdown]
# **Defining model object**

# %%
model = PHN(qlayer)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# %%
from torchsummary import summary

# %%
summary(model, input_size=(3, 128, 128))
# summary(model, input_size=(3, 180, 180))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#            Flatten-1                [-1, 49152]               0
#             Linear-2                   [-1, 64]       3,145,792
#            Dropout-3                   [-1, 64]               0
#        BatchNorm1d-4                   [-1, 64]             128
#             Linear-5                   [-1, 32]           2,080
#            Dropout-6                   [-1, 32]               0
#        BatchNorm1d-7                   [-1, 32]              64
#             Linear-8                   [-1, 16]             528
#            Dropout-9                   [-1, 16]               0
#       BatchNorm1d-10                   [-1, 16]              32
#        TorchLayer-11                       [-1]               0
#        TorchLayer-12                       [-1]               0
#            Linear-13                   [-1, 16]             144
#           Dropout-14                   [-1, 16]               0
#         LayerNorm-15                   [-1, 16]              32
#            Linear-16                    [-1, 8]             136
#           Dropout-17                    [-1, 8]               0
#         LayerNorm-18                    [-1, 8]              16
#            Linear-19                    [-1, 8]             104
#           Dropout-20                    [-1, 8]               0
#         LayerNorm-21                    [-1, 8]              16
#            Linear-22                    [-1, 6]              54
#           Softmax-23                    [-1, 6]               0
# ================================================================
# Total params: 3,149,126
# Trainable params: 3,149,126
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.19
# Forward/backward pass size (MB): 0.38
# Params size (MB): 12.01
# Estimated Total Size (MB): 12.58
# ----------------------------------------------------------------

# %% [markdown]
# **Optimizer and stuff**

# %%
opt = torch.optim.SGD(model.parameters(), lr=0.002)
loss = nn.CrossEntropyLoss()

# %%
if image.ndim == 2:
    image_expanded = np.stack((image,)*3, axis=0)

# %%
image_expanded.shape, image.shape
# Out:
# ((3, 128, 128), (128, 128))

# %%
# Define the batch size
batch_size = 32  # You can choose any batch size

# Create a random input tensor
batch_input_tensor = torch.randn(batch_size, 3, 128, 128)  # Random tensor with shape (batch_size, 3, 128, 128)

# Print the shape of the input tensor
print(batch_input_tensor.shape)  # Should print: torch.Size([8, 3, 128, 128])
# Out:
# torch.Size([32, 3, 128, 128])

# %%
single_image_input = torch.randn(1, 3, 128, 128)  # A random single image

# Print the shape of the input tensor
print(single_image_input.shape)  # Should print: torch.Size([1, 3, 128, 128])
# Out:
# torch.Size([1, 3, 128, 128])

# %%
batch_input_tensor = batch_input_tensor.to(device)
single_image_input = single_image_input.to(device)

# model = model.to(device)

# model(single_image_input)
model(batch_input_tensor)
# Out:
# tensor([[0.2066, 0.2298, 0.1382, 0.1775, 0.0522, 0.1957],
#         [0.1312, 0.1454, 0.3401, 0.1831, 0.0489, 0.1513],
#         [0.1760, 0.0689, 0.2197, 0.1060, 0.3175, 0.1120],
#         [0.4405, 0.2400, 0.0684, 0.0828, 0.0555, 0.1128],
#         [0.4566, 0.1168, 0.0866, 0.0876, 0.1307, 0.1216],
#         [0.2521, 0.0374, 0.1641, 0.1202, 0.2918, 0.1344],
#         [0.4396, 0.1495, 0.0620, 0.1127, 0.1208, 0.1155],
#         [0.1312, 0.1454, 0.3401, 0.1831, 0.0489, 0.1513],
#         [0.1551, 0.2179, 0.2242, 0.0801, 0.1502, 0.1724],
#         [0.5475, 0.0710, 0.0947, 0.0628, 0.1143, 0.1097],
#         [0.5438, 0.0791, 0.1457, 0.0493, 0.0961, 0.0860],
#         [0.4966, 0.0952, 0.0877, 0.0788, 0.1246, 0.1171],
#         [0.0833, 0.1671, 0.3041, 0.0893, 0.1568, 0.1994],
#         [0.0778, 0.2337, 0.1992, 0.1057, 0.1593, 0.2242],
#         [0.5507, 0.1270, 0.0899, 0.0660, 0.0924, 0.0741],
#         [0.1211, 0.1472, 0.2971, 0.0804, 0.1893, 0.1649],
#         [0.1706, 0.0969, 0.3230, 0.0683, 0.2000, 0.1412],
#         [0.0657, 0.2114, 0.3174, 0.1172, 0.1071, 0.1813],
#         [0.3581, 0.0498, 0.2504, 0.0635, 0.1708, 0.1075],
#         [0.5278, 0.0741, 0.1569, 0.0501, 0.1033, 0.0877],
#         [0.1371, 0.0588, 0.1677, 0.1470, 0.3243, 0.1650],
#         [0.2707, 0.0909, 0.2081, 0.1096, 0.1664, 0.1543],
#         [0.5779, 0.0982, 0.1026, 0.0573, 0.0889, 0.0751],
#         [0.0971, 0.2304, 0.1749, 0.1016, 0.1554, 0.2406],
#         [0.5416, 0.0909, 0.0780, 0.0737, 0.1153, 0.1007],
#         [0.5852, 0.0732, 0.1023, 0.0568, 0.1056, 0.0769],
#         [0.0966, 0.1601, 0.2782, 0.0914, 0.1906, 0.1831],
#         [0.2306, 0.2652, 0.0755, 0.1483, 0.1286, 0.1517],
#         [0.3697, 0.2578, 0.0648, 0.1167, 0.0751, 0.1159],
#         [0.3570, 0.0323, 0.2051, 0.0696, 0.1998, 0.1361],
#         [0.1312, 0.1454, 0.3401, 0.1831, 0.0489, 0.1513],
#         [0.5479, 0.0757, 0.0881, 0.0648, 0.1240, 0.0994]],
#        grad_fn=<SoftmaxBackward0>)

# %% [markdown]
# **train and test division for the training and testing dataset**

# %%
# train_sub = image_dataset_from_directory(base_path,
#                                          labels="inferred",
#                                          label_mode="categorical",
#                                          image_size=(180, 180),
#                                          subset='training',
#                                          seed=1,
#                                          validation_split=0.2,
#                                          batch_size=32)

# test_sub = image_dataset_from_directory(base_path,
#                                         labels="inferred",
#                                         label_mode="categorical",
#                                         image_size=(180, 180),
#                                         subset='validation',
#                                         seed=1,
#                                         validation_split=0.2,
#                                         batch_size=32)

# %%
from torchvision import datasets, transforms

# transform = transforms.Compose([
#     transforms.Resize((180, 180)),
#     transforms.ToTensor()
# ])

transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor()
])

# %%
full_dataset = datasets.ImageFolder(root=base_path, transform=transform)

validation_split = 0.3
dataset_size = len(full_dataset)
val_size = int(validation_split * dataset_size)
train_size = dataset_size - val_size

# %%
from torch.utils.data import DataLoader, random_split

train_sub, test_sub = random_split(full_dataset, [train_size, val_size], generator=torch.Generator().manual_seed(1))

# %%
train_loader = DataLoader(train_sub, batch_size=32, shuffle=True)
test_loader = DataLoader(test_sub, batch_size=32, shuffle=True)

# %%
def calc_acc(outputs, labels):
    _, predicted = torch.max(outputs, 1)
    correct = (predicted == labels).sum().item()
    accuracy = correct / labels.size(0)
    return accuracy

# %%
num_epochs = 30
# num_epochs = 5
# num_epochs = 1

loss_at_epoch = []
acc_at_epoch = []

running_loss_at_epoch = []
running_acc_at_epoch = []

# %% [markdown]
# **Checking the train and test loaders**

# %%
batch_counter = 1
for inputs, labels in train_loader:
    # print("batch_counter:", batch_counter)
    # print("shape of inputs:", inputs.shape)
    # print("shape of labels:", labels.shape)
    batch_counter += 1

print("num batches:", batch_counter)
# Out:
# num batches: 585

# %%
batch_counter = 1
for inputs, labels in test_loader:
    # print("batch_counter:", batch_counter)
    # print("shape of inputs:", inputs.shape)
    # print("shape of labels:", labels.shape)
    batch_counter += 1

print("num batches in test loader:", batch_counter)
# Out:
# num batches in test loader: 251

# %% [markdown]
# **Continuing with training**

# %%
PATH = 'data'

# %%
import time

for epoch in range(num_epochs):
    running_loss = 0.0
    running_acc = 0.0
    batch_counter = 1
    
    for inputs, labels in train_loader:
        start_time = time.time()
        print("epoch, batch_counter start:", epoch + 1, batch_counter)
        
        opt.zero_grad()
        inputs = inputs.to(device)
        labels = labels.to(device)

        outputs = model(inputs)
        l = loss(outputs, labels)

        print("l:", l)
        # print("output from model:", outputs)
        # print("labels in iteration:", labels)

        l.backward()
        opt.step()

        acc = calc_acc(outputs, labels)
        # if batch_counter == 1:
        if True:
            print("acc:", acc)

        loss_at_epoch.append(l.item())
        acc_at_epoch.append(acc)

        running_loss += l.item()
        running_acc += acc
        
        running_loss_at_epoch.append(running_loss)
        running_acc_at_epoch.append(running_acc)
        end_time = time.time()

        print("time taken:", end_time - start_time)
        batch_counter += 1

    epoch_loss = running_loss / len(train_loader)
    epoch_acc = running_acc / len(train_loader)
    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss:.4f}, Accuracy: {epoch_acc:.4f}")

    try:
        torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': opt.state_dict(),
            'loss': l,
            'loss_at_epoch': loss_at_epoch,
            'acc_at_epoch': acc_at_epoch,
            'running_loss_epoch': running_loss_at_epoch,
            'running_acc_epoch': running_acc_at_epoch
        }, PATH + 'epoch_' + str(epoch) + '.pth')
    except:
        print("Error in saving the model training params for the epoch")
# Out:
# epoch, batch_counter start: 1 1
# l: tensor(1.7919, grad_fn=<NllLossBackward0>)
# acc: 0.21875
# time taken: 1.3828999996185303
# epoch, batch_counter start: 1 2
# l: tensor(1.8156, grad_fn=<NllLossBackward0>)
# acc: 0.125
# time taken: 0.9370841979980469
# epoch, batch_counter start: 1 3
# l: tensor(1.7366, grad_fn=<NllLossBackward0>)
# acc: 0.3125
# time taken: 1.2164552211761475
# epoch, batch_counter start: 1 4
# l: tensor(1.7970, grad_fn=<NllLossBackward0>)
# acc: 0.1875
# time taken: 0.816964864730835
# epoch, batch_counter start: 1 5
# l: tensor(1.7936, grad_fn=<NllLossBackward0>)
# acc: 0.1875
# time taken: 0.7931389808654785
# epoch, batch_counter start: 1 6
# l: tensor(1.7652, grad_fn=<NllLossBackward0>)
# acc: 0.3125
# time taken: 1.184826135635376
# epoch, batch_counter start: 1 7
# l: tensor(1.7355, grad_fn=<NllLossBackward0>)
# acc: 0.375
# time taken: 0.9255077838897705
# epoch, batch_counter start: 1 8
# l: tensor(1.8097, grad_fn=<NllLossBackward0>)
# acc: 0.1875
# time taken: 1.109724998474121
# epoch, batch_counter start: 1 9
# l: tensor(1.7632, grad_fn=<NllLossBackward0>)
# acc: 0.21875
# time taken: 1.6309449672698975
# epoch, batch_counter start: 1 10
# l: tensor(1.7349, grad_fn=<NllLossBackward0>)
# acc: 0.34375
# time taken: 1.1427083015441895
# epoch, batch_counter start: 1 11
# l: tensor(1.7332, grad_fn=<NllLossBackward0>)
# acc: 0.28125
# time taken: 0.9237627983093262
# epoch, batch_counter start: 1 12
# l: tensor(1.7658, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 0.8763010501861572
# epoch, batch_counter start: 1 13
# l: tensor(1.7369, grad_fn=<NllLossBackward0>)
# acc: 0.3125
# time taken: 0.8305411338806152
# epoch, batch_counter start: 1 14
# l: tensor(1.8052, grad_fn=<NllLossBackward0>)
# acc: 0.15625
# time taken: 0.8107693195343018
# epoch, batch_counter start: 1 15
# l: tensor(1.7719, grad_fn=<NllLossBackward0>)
# acc: 0.15625
# time taken: 0.854356050491333
# epoch, batch_counter start: 1 16
# l: tensor(1.7593, grad_fn=<NllLossBackward0>)
# acc: 0.1875
# time taken: 0.7865068912506104
# epoch, batch_counter start: 1 17
# l: tensor(1.7402, grad_fn=<NllLossBackward0>)
# acc: 0.4375
# time taken: 0.8184072971343994
# epoch, batch_counter start: 1 18
# l: tensor(1.7699, grad_fn=<NllLossBackward0>)
# acc: 0.28125
# time taken: 0.8099431991577148
# epoch, batch_counter start: 1 19
# l: tensor(1.7550, grad_fn=<NllLossBackward0>)
# acc: 0.3125
# time taken: 0.7990541458129883
# epoch, batch_counter start: 1 20
# l: tensor(1.7326, grad_fn=<NllLossBackward0>)
# acc: 0.375
# time taken: 0.8100290298461914
# epoch, batch_counter start: 1 21
# l: tensor(1.7536, grad_fn=<NllLossBackward0>)
# acc: 0.3125
# time taken: 0.8529629707336426
# epoch, batch_counter start: 1 22
# l: tensor(1.7838, grad_fn=<NllLossBackward0>)
# acc: 0.1875
# time taken: 1.9791078567504883
# epoch, batch_counter start: 1 23
# l: tensor(1.6862, grad_fn=<NllLossBackward0>)
# acc: 0.40625
# time taken: 1.0671651363372803
# epoch, batch_counter start: 1 24
# l: tensor(1.7886, grad_fn=<NllLossBackward0>)
# acc: 0.21875
# time taken: 6.9550697803497314
# epoch, batch_counter start: 1 25
# l: tensor(1.7869, grad_fn=<NllLossBackward0>)
# acc: 0.15625
# time taken: 0.8208959102630615
# epoch, batch_counter start: 1 26
# l: tensor(1.7748, grad_fn=<NllLossBackward0>)
# acc: 0.28125
# time taken: 0.6888930797576904
# epoch, batch_counter start: 1 27
# l: tensor(1.7432, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 0.7219860553741455
# epoch, batch_counter start: 1 28
# l: tensor(1.7698, grad_fn=<NllLossBackward0>)
# acc: 0.1875
# time taken: 0.700859785079956
# epoch, batch_counter start: 1 29
# l: tensor(1.7623, grad_fn=<NllLossBackward0>)
# acc: 0.34375
# time taken: 0.6895248889923096
# epoch, batch_counter start: 1 30
# l: tensor(1.7432, grad_fn=<NllLossBackward0>)
# acc: 0.28125
# time taken: 0.679131031036377
# epoch, batch_counter start: 1 31
# l: tensor(1.7221, grad_fn=<NllLossBackward0>)
# acc: 0.3125
# time taken: 0.698570966720581
# epoch, batch_counter start: 1 32
# l: tensor(1.7435, grad_fn=<NllLossBackward0>)
# acc: 0.3125
# time taken: 0.7033319473266602
# epoch, batch_counter start: 1 33
# l: tensor(1.7827, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 0.6837739944458008
# epoch, batch_counter start: 1 34
# l: tensor(1.7296, grad_fn=<NllLossBackward0>)
# acc: 0.34375
# time taken: 0.6927950382232666
# epoch, batch_counter start: 1 35
# l: tensor(1.7767, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 0.6817977428436279
# epoch, batch_counter start: 1 36
# l: tensor(1.8101, grad_fn=<NllLossBackward0>)
# acc: 0.1875
# time taken: 0.7488439083099365
# epoch, batch_counter start: 1 37
# l: tensor(1.7596, grad_fn=<NllLossBackward0>)
# acc: 0.28125
# time taken: 0.6956279277801514
# epoch, batch_counter start: 1 38
# l: tensor(1.7422, grad_fn=<NllLossBackward0>)
# acc: 0.34375
# time taken: 0.7957170009613037
# epoch, batch_counter start: 1 39
# l: tensor(1.7835, grad_fn=<NllLossBackward0>)
# acc: 0.21875
# time taken: 0.8591549396514893
# epoch, batch_counter start: 1 40
# l: tensor(1.7890, grad_fn=<NllLossBackward0>)
# acc: 0.1875
# time taken: 0.852571964263916
# epoch, batch_counter start: 1 41
# l: tensor(1.7616, grad_fn=<NllLossBackward0>)
# acc: 0.21875
# time taken: 1.8189918994903564
# epoch, batch_counter start: 1 42
# l: tensor(1.7837, grad_fn=<NllLossBackward0>)
# acc: 0.15625
# time taken: 1.5163428783416748
# epoch, batch_counter start: 1 43
# l: tensor(1.7640, grad_fn=<NllLossBackward0>)
# acc: 0.3125
# time taken: 1.1636207103729248
# epoch, batch_counter start: 1 44
# l: tensor(1.7141, grad_fn=<NllLossBackward0>)
# acc: 0.40625
# time taken: 0.8163802623748779
# epoch, batch_counter start: 1 45
# l: tensor(1.7818, grad_fn=<NllLossBackward0>)
# acc: 0.1875
# time taken: 0.8162858486175537
# epoch, batch_counter start: 1 46
# l: tensor(1.7824, grad_fn=<NllLossBackward0>)
# acc: 0.15625
# time taken: 1.0233209133148193
# epoch, batch_counter start: 1 47
# l: tensor(1.7607, grad_fn=<NllLossBackward0>)
# acc: 0.28125
# time taken: 1.1345980167388916
# epoch, batch_counter start: 1 48
# l: tensor(1.7942, grad_fn=<NllLossBackward0>)
# acc: 0.1875
# time taken: 2.083311080932617
# epoch, batch_counter start: 1 49
# l: tensor(1.7026, grad_fn=<NllLossBackward0>)
# acc: 0.53125
# time taken: 0.8428089618682861
# epoch, batch_counter start: 1 50
# l: tensor(1.7884, grad_fn=<NllLossBackward0>)
# acc: 0.1875
# time taken: 0.8081369400024414
# epoch, batch_counter start: 1 51
# l: tensor(1.7573, grad_fn=<NllLossBackward0>)
# acc: 0.28125
# time taken: 0.8788762092590332
# epoch, batch_counter start: 1 52
# l: tensor(1.7369, grad_fn=<NllLossBackward0>)
# acc: 0.28125
# time taken: 1.0543861389160156
# epoch, batch_counter start: 1 53
# l: tensor(1.7325, grad_fn=<NllLossBackward0>)
# acc: 0.3125
# time taken: 1.1236178874969482
# epoch, batch_counter start: 1 54
# l: tensor(1.7682, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 0.8340508937835693
# epoch, batch_counter start: 1 55
# l: tensor(1.8338, grad_fn=<NllLossBackward0>)
# acc: 0.09375
# time taken: 0.9575040340423584
# epoch, batch_counter start: 1 56
# l: tensor(1.7654, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 0.8751320838928223
# epoch, batch_counter start: 1 57
# l: tensor(1.7482, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 3.381967782974243
# epoch, batch_counter start: 1 58
# l: tensor(1.7144, grad_fn=<NllLossBackward0>)
# acc: 0.375
# time taken: 1.4403181076049805
# epoch, batch_counter start: 1 59
# l: tensor(1.7387, grad_fn=<NllLossBackward0>)
# acc: 0.34375
# time taken: 1.0808088779449463
# epoch, batch_counter start: 1 60
# l: tensor(1.7243, grad_fn=<NllLossBackward0>)
# acc: 0.34375
# time taken: 0.8888452053070068
# epoch, batch_counter start: 1 61
# l: tensor(1.7361, grad_fn=<NllLossBackward0>)
# acc: 0.3125
# time taken: 0.8291840553283691
# epoch, batch_counter start: 1 62
# l: tensor(1.7525, grad_fn=<NllLossBackward0>)
# acc: 0.3125
# time taken: 0.8044931888580322
# epoch, batch_counter start: 1 63
# l: tensor(1.8167, grad_fn=<NllLossBackward0>)
# acc: 0.21875
# time taken: 0.816626787185669
# epoch, batch_counter start: 1 64
# l: tensor(1.7664, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 0.8687667846679688
# epoch, batch_counter start: 1 65
# l: tensor(1.7457, grad_fn=<NllLossBackward0>)
# acc: 0.28125
# time taken: 0.8699469566345215
# epoch, batch_counter start: 1 66
# l: tensor(1.8138, grad_fn=<NllLossBackward0>)
# acc: 0.125
# time taken: 0.852482795715332
# epoch, batch_counter start: 1 67
# l: tensor(1.7973, grad_fn=<NllLossBackward0>)
# acc: 0.21875
# time taken: 0.799292802810669
# epoch, batch_counter start: 1 68
# l: tensor(1.7800, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 0.7961740493774414
# epoch, batch_counter start: 1 69
# l: tensor(1.7650, grad_fn=<NllLossBackward0>)
# acc: 0.3125
# time taken: 0.816277027130127
# epoch, batch_counter start: 1 70
# l: tensor(1.7733, grad_fn=<NllLossBackward0>)
# acc: 0.21875
# time taken: 1.277129888534546
# epoch, batch_counter start: 1 71
# l: tensor(1.7706, grad_fn=<NllLossBackward0>)
# acc: 0.28125
# time taken: 0.858375072479248
# epoch, batch_counter start: 1 72
# l: tensor(1.7731, grad_fn=<NllLossBackward0>)
# acc: 0.1875
# time taken: 0.7872738838195801
# epoch, batch_counter start: 1 73
# l: tensor(1.7915, grad_fn=<NllLossBackward0>)
# acc: 0.1875
# time taken: 0.9055051803588867
# epoch, batch_counter start: 1 74
# l: tensor(1.7977, grad_fn=<NllLossBackward0>)
# acc: 0.15625
# time taken: 1.4198660850524902
# epoch, batch_counter start: 1 75
# l: tensor(1.7655, grad_fn=<NllLossBackward0>)
# acc: 0.28125
# time taken: 1.104813814163208
# epoch, batch_counter start: 1 76
# l: tensor(1.7716, grad_fn=<NllLossBackward0>)
# acc: 0.3125
# time taken: 0.8546857833862305
# epoch, batch_counter start: 1 77
# l: tensor(1.7595, grad_fn=<NllLossBackward0>)
# acc: 0.28125
# time taken: 0.8869221210479736
# epoch, batch_counter start: 1 78
# l: tensor(1.7996, grad_fn=<NllLossBackward0>)
# acc: 0.21875
# time taken: 1.041888952255249
# epoch, batch_counter start: 1 79
# l: tensor(1.7781, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 0.9225611686706543
# epoch, batch_counter start: 1 80
# l: tensor(1.7713, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 0.8086950778961182
# epoch, batch_counter start: 1 81
# l: tensor(1.7320, grad_fn=<NllLossBackward0>)
# acc: 0.40625
# time taken: 0.8176817893981934
# epoch, batch_counter start: 1 82
# l: tensor(1.8170, grad_fn=<NllLossBackward0>)
# acc: 0.125
# time taken: 0.87294602394104
# epoch, batch_counter start: 1 83
# l: tensor(1.7627, grad_fn=<NllLossBackward0>)
# acc: 0.28125
# time taken: 0.8196711540222168
# epoch, batch_counter start: 1 84
# l: tensor(1.7429, grad_fn=<NllLossBackward0>)
# acc: 0.3125
# time taken: 0.8438699245452881
# epoch, batch_counter start: 1 85
# l: tensor(1.7397, grad_fn=<NllLossBackward0>)
# acc: 0.375
# time taken: 1.0199508666992188
# epoch, batch_counter start: 1 86
# l: tensor(1.7164, grad_fn=<NllLossBackward0>)
# acc: 0.40625
# time taken: 0.8061752319335938
# epoch, batch_counter start: 1 87
# l: tensor(1.7872, grad_fn=<NllLossBackward0>)
# acc: 0.21875
# time taken: 1.3644192218780518
# epoch, batch_counter start: 1 88
# l: tensor(1.7854, grad_fn=<NllLossBackward0>)
# acc: 0.21875
# time taken: 0.8262770175933838
# epoch, batch_counter start: 1 89
# l: tensor(1.7531, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 1.0870909690856934
# epoch, batch_counter start: 1 90
# l: tensor(1.7858, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 0.9503109455108643
# epoch, batch_counter start: 1 91
# l: tensor(1.7918, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 0.8480358123779297
# epoch, batch_counter start: 1 92
# l: tensor(1.7330, grad_fn=<NllLossBackward0>)
# acc: 0.3125
# time taken: 1.0013680458068848
# epoch, batch_counter start: 1 93
# l: tensor(1.7801, grad_fn=<NllLossBackward0>)
# acc: 0.15625
# time taken: 1.0317251682281494
# epoch, batch_counter start: 1 94
# l: tensor(1.7604, grad_fn=<NllLossBackward0>)
# acc: 0.3125
# time taken: 0.9475440979003906
# epoch, batch_counter start: 1 95
# l: tensor(1.7817, grad_fn=<NllLossBackward0>)
# acc: 0.1875
# time taken: 1.0012998580932617
# epoch, batch_counter start: 1 96
# l: tensor(1.7567, grad_fn=<NllLossBackward0>)
# acc: 0.28125
# time taken: 0.818889856338501
# epoch, batch_counter start: 1 97
# l: tensor(1.7790, grad_fn=<NllLossBackward0>)
# acc: 0.21875
# time taken: 0.9062929153442383
# epoch, batch_counter start: 1 98
# l: tensor(1.7451, grad_fn=<NllLossBackward0>)
# acc: 0.4375
# time taken: 0.8299939632415771
# epoch, batch_counter start: 1 99
# l: tensor(1.7875, grad_fn=<NllLossBackward0>)
# acc: 0.1875
# time taken: 0.9887361526489258
# epoch, batch_counter start: 1 100
# l: tensor(1.8196, grad_fn=<NllLossBackward0>)
# acc: 0.125
# time taken: 1.2480530738830566
# epoch, batch_counter start: 1 101
# l: tensor(1.7609, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 1.1600751876831055
# epoch, batch_counter start: 1 102
# l: tensor(1.7926, grad_fn=<NllLossBackward0>)
# acc: 0.15625
# time taken: 0.9744677543640137
# epoch, batch_counter start: 1 103
# l: tensor(1.7434, grad_fn=<NllLossBackward0>)
# acc: 0.3125
# time taken: 1.0241799354553223
# epoch, batch_counter start: 1 104
# l: tensor(1.7534, grad_fn=<NllLossBackward0>)
# acc: 0.21875
# time taken: 0.7920539379119873
# epoch, batch_counter start: 1 105
# l: tensor(1.7193, grad_fn=<NllLossBackward0>)
# acc: 0.34375
# time taken: 0.7949347496032715
# epoch, batch_counter start: 1 106
# l: tensor(1.7117, grad_fn=<NllLossBackward0>)
# acc: 0.40625
# time taken: 0.7928340435028076
# epoch, batch_counter start: 1 107
# l: tensor(1.7245, grad_fn=<NllLossBackward0>)
# acc: 0.40625
# time taken: 0.8137080669403076
# epoch, batch_counter start: 1 108
# l: tensor(1.7425, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 0.8088750839233398
# epoch, batch_counter start: 1 109
# l: tensor(1.7911, grad_fn=<NllLossBackward0>)
# acc: 0.1875
# time taken: 0.8611810207366943
# epoch, batch_counter start: 1 110
# l: tensor(1.7522, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 0.7931969165802002
# epoch, batch_counter start: 1 111
# l: tensor(1.7657, grad_fn=<NllLossBackward0>)
# acc: 0.21875
# time taken: 0.8859126567840576
# epoch, batch_counter start: 1 112
# l: tensor(1.7713, grad_fn=<NllLossBackward0>)
# acc: 0.28125
# time taken: 0.8682470321655273
# epoch, batch_counter start: 1 113
# l: tensor(1.8095, grad_fn=<NllLossBackward0>)
# acc: 0.21875
# time taken: 1.1206169128417969
# epoch, batch_counter start: 1 114
# l: tensor(1.7505, grad_fn=<NllLossBackward0>)
# acc: 0.34375
# time taken: 0.948962926864624
# epoch, batch_counter start: 1 115
# l: tensor(1.7643, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 0.9229748249053955
# epoch, batch_counter start: 1 116
# l: tensor(1.7856, grad_fn=<NllLossBackward0>)
# acc: 0.1875
# time taken: 0.9655129909515381
# epoch, batch_counter start: 1 117
# l: tensor(1.7642, grad_fn=<NllLossBackward0>)
# acc: 0.3125
# time taken: 1.311777114868164
# epoch, batch_counter start: 1 118
# l: tensor(1.8127, grad_fn=<NllLossBackward0>)
# acc: 0.125
# time taken: 0.8810970783233643
# epoch, batch_counter start: 1 119
# l: tensor(1.7303, grad_fn=<NllLossBackward0>)
# acc: 0.34375
# time taken: 0.961522102355957
# epoch, batch_counter start: 1 120
# l: tensor(1.7479, grad_fn=<NllLossBackward0>)
# acc: 0.28125
# time taken: 0.8639233112335205
# epoch, batch_counter start: 1 121
# l: tensor(1.8319, grad_fn=<NllLossBackward0>)
# acc: 0.125
# time taken: 0.8942699432373047
# epoch, batch_counter start: 1 122
# l: tensor(1.7585, grad_fn=<NllLossBackward0>)
# acc: 0.28125
# time taken: 1.1309618949890137
# epoch, batch_counter start: 1 123
# l: tensor(1.7625, grad_fn=<NllLossBackward0>)
# acc: 0.3125
# time taken: 1.6843700408935547
# epoch, batch_counter start: 1 124
# l: tensor(1.7325, grad_fn=<NllLossBackward0>)
# acc: 0.34375
# time taken: 1.5793311595916748
# epoch, batch_counter start: 1 125
# l: tensor(1.7296, grad_fn=<NllLossBackward0>)
# acc: 0.375
# time taken: 0.9626319408416748
# epoch, batch_counter start: 1 126
# l: tensor(1.7691, grad_fn=<NllLossBackward0>)
# acc: 0.28125
# time taken: 1.3391571044921875
# epoch, batch_counter start: 1 127
# l: tensor(1.7794, grad_fn=<NllLossBackward0>)
# acc: 0.28125
# time taken: 0.9293508529663086
# epoch, batch_counter start: 1 128
# l: tensor(1.7634, grad_fn=<NllLossBackward0>)
# acc: 0.21875
# time taken: 0.8243849277496338
# epoch, batch_counter start: 1 129
# l: tensor(1.7513, grad_fn=<NllLossBackward0>)
# acc: 0.28125
# time taken: 0.825383186340332
# epoch, batch_counter start: 1 130
# l: tensor(1.7993, grad_fn=<NllLossBackward0>)
# acc: 0.1875
# time taken: 1.0082521438598633
# epoch, batch_counter start: 1 131
# l: tensor(1.7722, grad_fn=<NllLossBackward0>)
# acc: 0.21875
# time taken: 1.0719690322875977
# epoch, batch_counter start: 1 132
# l: tensor(1.7620, grad_fn=<NllLossBackward0>)
# acc: 0.3125
# time taken: 0.8327891826629639
# epoch, batch_counter start: 1 133
# l: tensor(1.7498, grad_fn=<NllLossBackward0>)
# acc: 0.34375
# time taken: 0.8404927253723145
# epoch, batch_counter start: 1 134
# l: tensor(1.7325, grad_fn=<NllLossBackward0>)
# acc: 0.34375
# time taken: 0.8045639991760254
# epoch, batch_counter start: 1 135
# l: tensor(1.7226, grad_fn=<NllLossBackward0>)
# acc: 0.40625
# time taken: 1.0426661968231201
# epoch, batch_counter start: 1 136
# l: tensor(1.7169, grad_fn=<NllLossBackward0>)
# acc: 0.28125
# time taken: 1.560534954071045
# epoch, batch_counter start: 1 137
# l: tensor(1.7831, grad_fn=<NllLossBackward0>)
# acc: 0.1875
# time taken: 1.0836029052734375
# epoch, batch_counter start: 1 138
# l: tensor(1.7199, grad_fn=<NllLossBackward0>)
# acc: 0.4375
# time taken: 1.1642909049987793
# epoch, batch_counter start: 1 139
# l: tensor(1.7717, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 1.079268217086792
# epoch, batch_counter start: 1 140
# l: tensor(1.7416, grad_fn=<NllLossBackward0>)
# acc: 0.3125
# time taken: 0.9168970584869385
# epoch, batch_counter start: 1 141
# l: tensor(1.7618, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 0.8129351139068604
# epoch, batch_counter start: 1 142
# l: tensor(1.7804, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 0.8109920024871826
# epoch, batch_counter start: 1 143
# l: tensor(1.7587, grad_fn=<NllLossBackward0>)
# acc: 0.3125
# time taken: 0.7876980304718018
# epoch, batch_counter start: 1 144
# l: tensor(1.7731, grad_fn=<NllLossBackward0>)
# acc: 0.28125
# time taken: 0.7982311248779297
# epoch, batch_counter start: 1 145
# l: tensor(1.7690, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 0.8240759372711182
# epoch, batch_counter start: 1 146
# l: tensor(1.7802, grad_fn=<NllLossBackward0>)
# acc: 0.28125
# time taken: 0.8874697685241699
# epoch, batch_counter start: 1 147
# l: tensor(1.7296, grad_fn=<NllLossBackward0>)
# acc: 0.375
# time taken: 0.7935497760772705
# epoch, batch_counter start: 1 148
# l: tensor(1.7652, grad_fn=<NllLossBackward0>)
# acc: 0.21875
# time taken: 0.9429621696472168
# epoch, batch_counter start: 1 149
# l: tensor(1.7638, grad_fn=<NllLossBackward0>)
# acc: 0.3125
# time taken: 0.8064100742340088
# epoch, batch_counter start: 1 150
# l: tensor(1.7243, grad_fn=<NllLossBackward0>)
# acc: 0.375
# time taken: 0.9812679290771484
# epoch, batch_counter start: 1 151
# l: tensor(1.7429, grad_fn=<NllLossBackward0>)
# acc: 0.21875
# time taken: 0.9107980728149414
# epoch, batch_counter start: 1 152
# l: tensor(1.7943, grad_fn=<NllLossBackward0>)
# acc: 0.1875
# time taken: 0.798504114151001
# epoch, batch_counter start: 1 153
# l: tensor(1.7459, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 0.8581931591033936
# epoch, batch_counter start: 1 154
# l: tensor(1.7885, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 0.9465579986572266
# epoch, batch_counter start: 1 155
# l: tensor(1.7491, grad_fn=<NllLossBackward0>)
# acc: 0.3125
# time taken: 0.8369472026824951
# epoch, batch_counter start: 1 156
# l: tensor(1.7522, grad_fn=<NllLossBackward0>)
# acc: 0.34375
# time taken: 0.801652193069458
# epoch, batch_counter start: 1 157
# l: tensor(1.7373, grad_fn=<NllLossBackward0>)
# acc: 0.375
# time taken: 0.7879049777984619
# epoch, batch_counter start: 1 158
# l: tensor(1.7847, grad_fn=<NllLossBackward0>)
# acc: 0.1875
# time taken: 1.0960512161254883
# epoch, batch_counter start: 1 159
# l: tensor(1.7755, grad_fn=<NllLossBackward0>)
# acc: 0.28125
# time taken: 0.7212228775024414
# epoch, batch_counter start: 1 160
# l: tensor(1.7705, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 0.8042869567871094
# epoch, batch_counter start: 1 161
# l: tensor(1.7591, grad_fn=<NllLossBackward0>)
# acc: 0.3125
# time taken: 0.8030858039855957
# epoch, batch_counter start: 1 162
# l: tensor(1.7656, grad_fn=<NllLossBackward0>)
# acc: 0.3125
# time taken: 0.7940189838409424
# epoch, batch_counter start: 1 163
# l: tensor(1.7293, grad_fn=<NllLossBackward0>)
# acc: 0.4375
# time taken: 0.858086109161377
# epoch, batch_counter start: 1 164
# l: tensor(1.7847, grad_fn=<NllLossBackward0>)
# acc: 0.1875
# time taken: 0.8839898109436035
# epoch, batch_counter start: 1 165
# l: tensor(1.7763, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 0.8035290241241455
# epoch, batch_counter start: 1 166
# l: tensor(1.7608, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 1.2902021408081055
# epoch, batch_counter start: 1 167
# l: tensor(1.8071, grad_fn=<NllLossBackward0>)
# acc: 0.1875
# time taken: 1.1613528728485107
# epoch, batch_counter start: 1 168
# l: tensor(1.7795, grad_fn=<NllLossBackward0>)
# acc: 0.1875
# time taken: 1.0915050506591797
# epoch, batch_counter start: 1 169
# l: tensor(1.7750, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 0.8717200756072998
# epoch, batch_counter start: 1 170
# l: tensor(1.7317, grad_fn=<NllLossBackward0>)
# acc: 0.28125
# time taken: 0.8325450420379639
# epoch, batch_counter start: 1 171
# l: tensor(1.7378, grad_fn=<NllLossBackward0>)
# acc: 0.375
# time taken: 0.8619978427886963
# epoch, batch_counter start: 1 172
# l: tensor(1.7578, grad_fn=<NllLossBackward0>)
# acc: 0.28125
# time taken: 0.9701797962188721
# epoch, batch_counter start: 1 173
# l: tensor(1.7704, grad_fn=<NllLossBackward0>)
# acc: 0.1875
# time taken: 1.0465898513793945
# epoch, batch_counter start: 1 174
# l: tensor(1.7625, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 0.8850827217102051
# epoch, batch_counter start: 1 175
# l: tensor(1.7865, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 0.962677001953125
# epoch, batch_counter start: 1 176
# l: tensor(1.7145, grad_fn=<NllLossBackward0>)
# acc: 0.375
# time taken: 1.2944929599761963
# epoch, batch_counter start: 1 177
# l: tensor(1.7500, grad_fn=<NllLossBackward0>)
# acc: 0.34375
# time taken: 1.0983870029449463
# epoch, batch_counter start: 1 178
# l: tensor(1.7250, grad_fn=<NllLossBackward0>)
# acc: 0.3125
# time taken: 0.936290979385376
# epoch, batch_counter start: 1 179
# l: tensor(1.7729, grad_fn=<NllLossBackward0>)
# acc: 0.28125
# time taken: 1.3436429500579834
# epoch, batch_counter start: 1 180
# l: tensor(1.7420, grad_fn=<NllLossBackward0>)
# acc: 0.3125
# time taken: 0.9398548603057861
# epoch, batch_counter start: 1 181
# l: tensor(1.7991, grad_fn=<NllLossBackward0>)
# acc: 0.1875
# time taken: 0.9882380962371826
# epoch, batch_counter start: 1 182
# l: tensor(1.7779, grad_fn=<NllLossBackward0>)
# acc: 0.3125
# time taken: 0.9495570659637451
# epoch, batch_counter start: 1 183
# l: tensor(1.7771, grad_fn=<NllLossBackward0>)
# acc: 0.21875
# time taken: 0.9409101009368896
# epoch, batch_counter start: 1 184
# l: tensor(1.7492, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 0.9528801441192627
# epoch, batch_counter start: 1 185
# l: tensor(1.7601, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 0.8562512397766113
# epoch, batch_counter start: 1 186
# l: tensor(1.7557, grad_fn=<NllLossBackward0>)
# acc: 0.375
# time taken: 0.7854771614074707
# epoch, batch_counter start: 1 187
# l: tensor(1.7098, grad_fn=<NllLossBackward0>)
# acc: 0.375
# time taken: 0.779681921005249
# epoch, batch_counter start: 1 188
# l: tensor(1.7938, grad_fn=<NllLossBackward0>)
# acc: 0.15625
# time taken: 0.7945799827575684
# epoch, batch_counter start: 1 189
# l: tensor(1.7392, grad_fn=<NllLossBackward0>)
# acc: 0.34375
# time taken: 0.7884936332702637
# epoch, batch_counter start: 1 190
# l: tensor(1.7794, grad_fn=<NllLossBackward0>)
# acc: 0.15625
# time taken: 0.774055004119873
# epoch, batch_counter start: 1 191
# l: tensor(1.7456, grad_fn=<NllLossBackward0>)
# acc: 0.34375
# time taken: 0.8916599750518799
# epoch, batch_counter start: 1 192
# l: tensor(1.8048, grad_fn=<NllLossBackward0>)
# acc: 0.21875
# time taken: 0.7925281524658203
# epoch, batch_counter start: 1 193
# l: tensor(1.7638, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 1.0801680088043213
# epoch, batch_counter start: 1 194
# l: tensor(1.8034, grad_fn=<NllLossBackward0>)
# acc: 0.1875
# time taken: 0.7040221691131592
# epoch, batch_counter start: 1 195
# l: tensor(1.7721, grad_fn=<NllLossBackward0>)
# acc: 0.3125
# time taken: 0.8944389820098877
# epoch, batch_counter start: 1 196
# l: tensor(1.7129, grad_fn=<NllLossBackward0>)
# acc: 0.40625
# time taken: 0.792182207107544
# epoch, batch_counter start: 1 197
# l: tensor(1.7907, grad_fn=<NllLossBackward0>)
# acc: 0.21875
# time taken: 0.9362039566040039
# epoch, batch_counter start: 1 198
# l: tensor(1.7768, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 1.0780930519104004
# epoch, batch_counter start: 1 199
# l: tensor(1.7798, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 0.8584651947021484
# epoch, batch_counter start: 1 200
# l: tensor(1.8062, grad_fn=<NllLossBackward0>)
# acc: 0.15625
# time taken: 0.9207930564880371
# epoch, batch_counter start: 1 201
# l: tensor(1.7337, grad_fn=<NllLossBackward0>)
# acc: 0.34375
# time taken: 0.795983076095581
# epoch, batch_counter start: 1 202
# l: tensor(1.7471, grad_fn=<NllLossBackward0>)
# acc: 0.34375
# time taken: 0.7804749011993408
# epoch, batch_counter start: 1 203
# l: tensor(1.7876, grad_fn=<NllLossBackward0>)
# acc: 0.21875
# time taken: 0.7767317295074463
# epoch, batch_counter start: 1 204
# l: tensor(1.7470, grad_fn=<NllLossBackward0>)
# acc: 0.34375
# time taken: 0.7759661674499512
# epoch, batch_counter start: 1 205
# l: tensor(1.7172, grad_fn=<NllLossBackward0>)
# acc: 0.40625
# time taken: 0.8290679454803467
# epoch, batch_counter start: 1 206
# l: tensor(1.7620, grad_fn=<NllLossBackward0>)
# acc: 0.3125
# time taken: 0.8012230396270752
# epoch, batch_counter start: 1 207
# l: tensor(1.7283, grad_fn=<NllLossBackward0>)
# acc: 0.375
# time taken: 0.7828590869903564
# epoch, batch_counter start: 1 208
# l: tensor(1.6888, grad_fn=<NllLossBackward0>)
# acc: 0.40625
# time taken: 0.7786598205566406
# epoch, batch_counter start: 1 209
# l: tensor(1.7225, grad_fn=<NllLossBackward0>)
# acc: 0.34375
# time taken: 0.8559331893920898
# epoch, batch_counter start: 1 210
# l: tensor(1.7788, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 0.78171706199646
# epoch, batch_counter start: 1 211
# l: tensor(1.7876, grad_fn=<NllLossBackward0>)
# acc: 0.1875
# time taken: 1.509200096130371
# epoch, batch_counter start: 1 212
# l: tensor(1.7780, grad_fn=<NllLossBackward0>)
# acc: 0.1875
# time taken: 1.028721809387207
# epoch, batch_counter start: 1 213
# l: tensor(1.7312, grad_fn=<NllLossBackward0>)
# acc: 0.40625
# time taken: 0.8707430362701416
# epoch, batch_counter start: 1 214
# l: tensor(1.7451, grad_fn=<NllLossBackward0>)
# acc: 0.3125
# time taken: 0.7786870002746582
# epoch, batch_counter start: 1 215
# l: tensor(1.7390, grad_fn=<NllLossBackward0>)
# acc: 0.3125
# time taken: 0.7938899993896484
# epoch, batch_counter start: 1 216
# l: tensor(1.8133, grad_fn=<NllLossBackward0>)
# acc: 0.125
# time taken: 0.7934041023254395
# epoch, batch_counter start: 1 217
# l: tensor(1.7556, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 0.8013167381286621
# epoch, batch_counter start: 1 218
# l: tensor(1.7814, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 0.785862922668457
# epoch, batch_counter start: 1 219
# l: tensor(1.7426, grad_fn=<NllLossBackward0>)
# acc: 0.3125
# time taken: 0.8875439167022705
# epoch, batch_counter start: 1 220
# l: tensor(1.7848, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 0.8054389953613281
# epoch, batch_counter start: 1 221
# l: tensor(1.7429, grad_fn=<NllLossBackward0>)
# acc: 0.3125
# time taken: 0.7898099422454834
# epoch, batch_counter start: 1 222
# l: tensor(1.7744, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 0.8302662372589111
# epoch, batch_counter start: 1 223
# l: tensor(1.7943, grad_fn=<NllLossBackward0>)
# acc: 0.15625
# time taken: 0.8557431697845459
# epoch, batch_counter start: 1 224
# l: tensor(1.7112, grad_fn=<NllLossBackward0>)
# acc: 0.375
# time taken: 0.8540780544281006
# epoch, batch_counter start: 1 225
# l: tensor(1.7637, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 0.9415862560272217
# epoch, batch_counter start: 1 226
# l: tensor(1.7514, grad_fn=<NllLossBackward0>)
# acc: 0.375
# time taken: 0.7876949310302734
# epoch, batch_counter start: 1 227
# l: tensor(1.7191, grad_fn=<NllLossBackward0>)
# acc: 0.34375
# time taken: 0.7861568927764893
# epoch, batch_counter start: 1 228
# l: tensor(1.7840, grad_fn=<NllLossBackward0>)
# acc: 0.21875
# time taken: 1.2754900455474854
# epoch, batch_counter start: 1 229
# l: tensor(1.8059, grad_fn=<NllLossBackward0>)
# acc: 0.15625
# time taken: 0.9210038185119629
# epoch, batch_counter start: 1 230
# l: tensor(1.7717, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 0.8767521381378174
# epoch, batch_counter start: 1 231
# l: tensor(1.7495, grad_fn=<NllLossBackward0>)
# acc: 0.28125
# time taken: 0.8023841381072998
# epoch, batch_counter start: 1 232
# l: tensor(1.7534, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 0.9774212837219238
# epoch, batch_counter start: 1 233
# l: tensor(1.7460, grad_fn=<NllLossBackward0>)
# acc: 0.28125
# time taken: 0.8108808994293213
# epoch, batch_counter start: 1 234
# l: tensor(1.7781, grad_fn=<NllLossBackward0>)
# acc: 0.21875
# time taken: 0.7993700504302979
# epoch, batch_counter start: 1 235
# l: tensor(1.7569, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 0.7955880165100098
# epoch, batch_counter start: 1 236
# l: tensor(1.7683, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 0.8294579982757568
# epoch, batch_counter start: 1 237
# l: tensor(1.7733, grad_fn=<NllLossBackward0>)
# acc: 0.3125
# time taken: 0.8067159652709961
# epoch, batch_counter start: 1 238
# l: tensor(1.7313, grad_fn=<NllLossBackward0>)
# acc: 0.3125
# time taken: 0.8031580448150635
# epoch, batch_counter start: 1 239
# l: tensor(1.7484, grad_fn=<NllLossBackward0>)
# acc: 0.28125
# time taken: 0.801278829574585
# epoch, batch_counter start: 1 240
# l: tensor(1.7485, grad_fn=<NllLossBackward0>)
# acc: 0.28125
# time taken: 0.7903537750244141
# epoch, batch_counter start: 1 241
# l: tensor(1.7559, grad_fn=<NllLossBackward0>)
# acc: 0.28125
# time taken: 0.7974209785461426
# epoch, batch_counter start: 1 242
# l: tensor(1.7392, grad_fn=<NllLossBackward0>)
# acc: 0.34375
# time taken: 1.3011341094970703
# epoch, batch_counter start: 1 243
# l: tensor(1.7143, grad_fn=<NllLossBackward0>)
# acc: 0.34375
# time taken: 0.803372859954834
# epoch, batch_counter start: 1 244
# l: tensor(1.7840, grad_fn=<NllLossBackward0>)
# acc: 0.1875
# time taken: 0.7926232814788818
# epoch, batch_counter start: 1 245
# l: tensor(1.7315, grad_fn=<NllLossBackward0>)
# acc: 0.4375
# time taken: 0.8608713150024414
# epoch, batch_counter start: 1 246
# l: tensor(1.7785, grad_fn=<NllLossBackward0>)
# acc: 0.25
# time taken: 2.1270101070404053
# epoch, batch_counter start: 1 247
# l: tensor(1.7659, grad_fn=<NllLossBackward0>)
# acc: 0.28125
# time taken: 0.903717041015625
# epoch, batch_counter start: 1 248
# l: tensor(1.7707, grad_fn=<NllLossBackward0>)
# acc: 0.21875
# time taken: 0.9101390838623047
# epoch, batch_counter start: 1 249
# l: tensor(1.7599, grad_fn=<NllLossBackward0>)
# acc: 0.3125
# time taken: 0.9795219898223877
# epoch, batch_counter start: 1 250
# l: tensor(1.7499, grad_fn=<NllLossBackward0>)
# acc: 0.3125
# time taken: 0.9447290897369385
# epoch, batch_counter start: 1 251
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 16
#      13 inputs = inputs.to(device)
#      14 labels = labels.to(device)
# ---> 16 outputs = model(inputs)
#      17 l = loss(outputs, labels)
#      19 print("l:", l)
#
# File ~/Downloads/Womanium/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/Downloads/Womanium/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# Cell In[10], line 441, in PHN.forward(self, x)
#     439 x_para_sig_q_ = []
#     440 for i in range(x_para_sig_quantum.shape[0]):
# --> 441     x_para_sig_q_item_temp = self.qlayer(x_para_sig_quantum[i])
#     442     x_para_sig_q_.append(x_para_sig_q_item_temp)
#     444 x_para_sig_q_ = torch.stack(x_para_sig_q_)
#
# File ~/Downloads/Womanium/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/Downloads/Womanium/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/Downloads/Womanium/.venv/lib/python3.11/site-packages/pennylane/qnn/torch.py:404, in TorchLayer.forward(self, inputs)
#     401     inputs = torch.reshape(inputs, (-1, inputs.shape[-1]))
#     403 # calculate the forward pass as usual
# --> 404 results = self._evaluate_qnode(inputs)
#     406 if isinstance(results, tuple):
#     407     if has_batch_dim:
#
# File ~/Downloads/Womanium/.venv/lib/python3.11/site-packages/pennylane/qnn/torch.py:430, in TorchLayer._evaluate_qnode(self, x)
#     418 """Evaluates the QNode for a single input datapoint.
#     419
#     420 Args:
#    (...)
#     424     tensor: output datapoint
#     425 """
#     426 kwargs = {
#     427     **{self.input_arg: x},
#     428     **{arg: weight.to(x) for arg, weight in self.qnode_weights.items()},
#     429 }
# --> 430 res = self.qnode(**kwargs)
#     432 if isinstance(res, torch.Tensor):
#     433     return res.type(x.dtype)
#
# File ~/Downloads/Womanium/.venv/lib/python3.11/site-packages/pennylane/workflow/qnode.py:987, in QNode.__call__(self, *args, **kwargs)
#     985 if qml.capture.enabled():
#     986     return qml.capture.qnode_call(self, *args, **kwargs)
# --> 987 return self._impl_call(*args, **kwargs)
#
# File ~/Downloads/Womanium/.venv/lib/python3.11/site-packages/pennylane/workflow/qnode.py:977, in QNode._impl_call(self, *args, **kwargs)
#     974     self._interface = interface
#     976 try:
# --> 977     res = self._execution_component(args, kwargs)
#     978 finally:
#     979     if old_interface == "auto":
#
# File ~/Downloads/Womanium/.venv/lib/python3.11/site-packages/pennylane/workflow/qnode.py:935, in QNode._execution_component(self, args, kwargs)
#     932 interface = None if self.interface == "numpy" else self.interface
#     934 # pylint: disable=unexpected-keyword-arg
# --> 935 res = qml.execute(
#     936     (self._tape,),
#     937     device=self.device,
#     938     gradient_fn=gradient_fn,
#     939     interface=interface,
#     940     transform_program=full_transform_program,
#     941     inner_transform=inner_transform_program,
#     942     config=config,
#     943     gradient_kwargs=gradient_kwargs,
#     944     **execute_kwargs,
#     945 )
#     946 res = res[0]
#     948 # convert result to the interface in case the qfunc has no parameters
#
# File ~/Downloads/Womanium/.venv/lib/python3.11/site-packages/pennylane/workflow/execution.py:523, in execute(tapes, device, gradient_fn, interface, transform_program, inner_transform, config, grad_on_execution, gradient_kwargs, cache, cachesize, max_diff, device_vjp, mcm_config)
#     521 # Exiting early if we do not need to deal with an interface boundary
#     522 if no_interface_boundary_required:
# --> 523     results = inner_execute(tapes)
#     524     return post_processing(results)
#     526 if config.use_device_jacobian_product and interface in jpc_interfaces:
#
# File ~/Downloads/Womanium/.venv/lib/python3.11/site-packages/pennylane/workflow/execution.py:202, in _make_inner_execute.<locals>.inner_execute(tapes, **_)
#     199 transformed_tapes, transform_post_processing = transform_program(tapes)
#     201 if transformed_tapes:
# --> 202     results = device.execute(transformed_tapes, execution_config=execution_config)
#     203 else:
#     204     results = ()
#
# File ~/Downloads/Womanium/.venv/lib/python3.11/site-packages/pennylane/devices/modifiers/simulator_tracking.py:30, in _track_execute.<locals>.execute(self, circuits, execution_config)
#      28 @wraps(untracked_execute)
#      29 def execute(self, circuits, execution_config=DefaultExecutionConfig):
# ---> 30     results = untracked_execute(self, circuits, execution_config)
#      31     if isinstance(circuits, QuantumScript):
#      32         batch = (circuits,)
#
# File ~/Downloads/Womanium/.venv/lib/python3.11/site-packages/pennylane/devices/modifiers/single_tape_support.py:32, in _make_execute.<locals>.execute(self, circuits, execution_config)
#      30     is_single_circuit = True
#      31     circuits = (circuits,)
# ---> 32 results = batch_execute(self, circuits, execution_config)
#      33 return results[0] if is_single_circuit else results
#
# File ~/Downloads/Womanium/.venv/lib/python3.11/site-packages/pennylane/logging/decorators.py:61, in log_string_debug_func.<locals>.wrapper_entry(*args, **kwargs)
#      54     s_caller = "::L".join(
#      55         [str(i) for i in inspect.getouterframes(inspect.currentframe(), 2)[1][1:3]]
#      56     )
#      57     lgr.debug(
#      58         f"Calling {f_string} from {s_caller}",
#      59         **_debug_log_kwargs,
#      60     )
# ---> 61 return func(*args, **kwargs)
#
# File ~/Downloads/Womanium/.venv/lib/python3.11/site-packages/pennylane/devices/default_qubit.py:642, in DefaultQubit.execute(self, circuits, execution_config)
#     639 prng_keys = [self.get_prng_keys()[0] for _ in range(len(circuits))]
#     641 if max_workers is None:
# --> 642     return tuple(
#     643         _simulate_wrapper(
#     644             c,
#     645             {
#     646                 "rng": self._rng,
#     647                 "debugger": self._debugger,
#     648                 "interface": interface,
#     649                 "state_cache": self._state_cache,
#     650                 "prng_key": _key,
#     651                 "mcm_method": execution_config.mcm_config.mcm_method,
#     652                 "postselect_mode": execution_config.mcm_config.postselect_mode,
#     653             },
#     654         )
#     655         for c, _key in zip(circuits, prng_keys)
#     656     )
#     658 vanilla_circuits = convert_to_numpy_parameters(circuits)[0]
#     659 seeds = self._rng.integers(2**31 - 1, size=len(vanilla_circuits))
#
# File ~/Downloads/Womanium/.venv/lib/python3.11/site-packages/pennylane/devices/default_qubit.py:643, in <genexpr>(.0)
#     639 prng_keys = [self.get_prng_keys()[0] for _ in range(len(circuits))]
#     641 if max_workers is None:
#     642     return tuple(
# --> 643         _simulate_wrapper(
#     644             c,
#     645             {
#     646                 "rng": self._rng,
#     647                 "debugger": self._debugger,
#     648                 "interface": interface,
#     649                 "state_cache": self._state_cache,
#     650                 "prng_key": _key,
#     651                 "mcm_method": execution_config.mcm_config.mcm_method,
#     652                 "postselect_mode": execution_config.mcm_config.postselect_mode,
#     653             },
#     654         )
#     655         for c, _key in zip(circuits, prng_keys)
#     656     )
#     658 vanilla_circuits = convert_to_numpy_parameters(circuits)[0]
#     659 seeds = self._rng.integers(2**31 - 1, size=len(vanilla_circuits))
#
# File ~/Downloads/Womanium/.venv/lib/python3.11/site-packages/pennylane/devices/default_qubit.py:908, in _simulate_wrapper(circuit, kwargs)
#     907 def _simulate_wrapper(circuit, kwargs):
# --> 908     return simulate(circuit, **kwargs)
#
# File ~/Downloads/Womanium/.venv/lib/python3.11/site-packages/pennylane/logging/decorators.py:61, in log_string_debug_func.<locals>.wrapper_entry(*args, **kwargs)
#      54     s_caller = "::L".join(
#      55         [str(i) for i in inspect.getouterframes(inspect.currentframe(), 2)[1][1:3]]
#      56     )
#      57     lgr.debug(
#      58         f"Calling {f_string} from {s_caller}",
#      59         **_debug_log_kwargs,
#      60     )
# ---> 61 return func(*args, **kwargs)
#
# File ~/Downloads/Womanium/.venv/lib/python3.11/site-packages/pennylane/devices/qubit/simulate.py:379, in simulate(circuit, debugger, state_cache, **execution_kwargs)
#     376     return tuple(results)
#     378 ops_key, meas_key = jax_random_split(prng_key)
# --> 379 state, is_state_batched = get_final_state(
#     380     circuit, debugger=debugger, prng_key=ops_key, **execution_kwargs
#     381 )
#     382 if state_cache is not None:
#     383     state_cache[circuit.hash] = state
#
# File ~/Downloads/Womanium/.venv/lib/python3.11/site-packages/pennylane/logging/decorators.py:61, in log_string_debug_func.<locals>.wrapper_entry(*args, **kwargs)
#      54     s_caller = "::L".join(
#      55         [str(i) for i in inspect.getouterframes(inspect.currentframe(), 2)[1][1:3]]
#      56     )
#      57     lgr.debug(
#      58         f"Calling {f_string} from {s_caller}",
#      59         **_debug_log_kwargs,
#      60     )
# ---> 61 return func(*args, **kwargs)
#
# File ~/Downloads/Womanium/.venv/lib/python3.11/site-packages/pennylane/devices/qubit/simulate.py:208, in get_final_state(circuit, debugger, **execution_kwargs)
#     206 if isinstance(op, MidMeasureMP):
#     207     prng_key, key = jax_random_split(prng_key)
# --> 208 state = apply_operation(
#     209     op,
#     210     state,
#     211     is_state_batched=is_state_batched,
#     212     debugger=debugger,
#     213     prng_key=key,
#     214     tape_shots=circuit.shots,
#     215     **execution_kwargs,
#     216 )
#     217 # Handle postselection on mid-circuit measurements
#     218 if isinstance(op, qml.Projector):
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/functools.py:909, in singledispatch.<locals>.wrapper(*args, **kw)
#     905 if not args:
#     906     raise TypeError(f'{funcname} requires at least '
#     907                     '1 positional argument')
# --> 909 return dispatch(args[0].__class__)(*args, **kw)
#
# File ~/Downloads/Womanium/.venv/lib/python3.11/site-packages/pennylane/devices/qubit/apply_operation.py:231, in apply_operation(op, state, is_state_batched, debugger, **_)
#     165 @singledispatch
#     166 def apply_operation(
#     167     op: qml.operation.Operator,
#    (...)
#     171     **_,
#     172 ):
#     173     """Apply and operator to a given state.
#     174
#     175     Args:
#    (...)
#     229
#     230     """
# --> 231     return _apply_operation_default(op, state, is_state_batched, debugger)
#
# File ~/Downloads/Womanium/.venv/lib/python3.11/site-packages/pennylane/devices/qubit/apply_operation.py:241, in _apply_operation_default(op, state, is_state_batched, debugger)
#     235 """The default behaviour of apply_operation, accessed through the standard dispatch
#     236 of apply_operation, as well as conditionally in other dispatches."""
#     237 if (
#     238     len(op.wires) < EINSUM_OP_WIRECOUNT_PERF_THRESHOLD
#     239     and math.ndim(state) < EINSUM_STATE_WIRECOUNT_PERF_THRESHOLD
#     240 ) or (op.batch_size and is_state_batched):
# --> 241     return apply_operation_einsum(op, state, is_state_batched=is_state_batched)
#     242 return apply_operation_tensordot(op, state, is_state_batched=is_state_batched)
#
# File ~/Downloads/Womanium/.venv/lib/python3.11/site-packages/pennylane/devices/qubit/apply_operation.py:80, in apply_operation_einsum(op, state, is_state_batched)
#      78     mat = qml.math.cast_like(op.matrix(), state)
#      79 else:
# ---> 80     mat = op.matrix() + 0j
#      82 total_indices = len(state.shape) - is_state_batched
#      83 num_indices = len(op.wires)
#
# File ~/Downloads/Womanium/.venv/lib/python3.11/site-packages/pennylane/operation.py:838, in Operator.matrix(self, wire_order)
#     818 def matrix(self, wire_order: Optional[WiresLike] = None) -> TensorLike:
#     819     r"""Representation of the operator as a matrix in the computational basis.
#     820
#     821     If ``wire_order`` is provided, the numerical representation considers the position of the
#    (...)
#     836         tensor_like: matrix representation
#     837     """
# --> 838     canonical_matrix = self.compute_matrix(*self.parameters, **self.hyperparameters)
#     840     if (
#     841         wire_order is None
#     842         or self.wires == Wires(wire_order)
#    (...)
#     846         )
#     847     ):
#     848         return canonical_matrix
#
# File ~/Downloads/Womanium/.venv/lib/python3.11/site-packages/pennylane/ops/qubit/parametric_ops_single_qubit.py:644, in Rot.compute_matrix(phi, theta, omega)
#     639 c = c * one
#     640 s = s * one
#     642 mat = [
#     643     [
# --> 644         qml.math.exp(-0.5j * (phi + omega)) * c,
#     645         -qml.math.exp(0.5j * (phi - omega)) * s,
#     646     ],
#     647     [
#     648         qml.math.exp(-0.5j * (phi - omega)) * s,
#     649         qml.math.exp(0.5j * (phi + omega)) * c,
#     650     ],
#     651 ]
#     653 return qml.math.stack([stack_last(row) for row in mat], axis=-2)
#
# File ~/Downloads/Womanium/.venv/lib/python3.11/site-packages/autoray/autoray.py:81, in do(fn, like, *args, **kwargs)
#      79 backend = _choose_backend(fn, args, kwargs, like=like)
#      80 func = get_lib_fn(backend, fn)
# ---> 81 return func(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
model.eval()
# Out:
# PHN(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (d1): Dropout(p=0.2, inplace=False)
#   (dense1): Linear(in_features=49152, out_features=64, bias=True)
#   (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dense2): Linear(in_features=64, out_features=32, bias=True)
#   (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dense3): Linear(in_features=32, out_features=16, bias=True)
#   (bn3): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dense4): Linear(in_features=8, out_features=16, bias=True)
#   (bn4): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (ln4): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#   (dense5): Linear(in_features=16, out_features=32, bias=True)
#   (bn5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (ln5): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#   (dense6): Linear(in_features=32, out_features=32, bias=True)
#   (bn6): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (ln6): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#   (dense7): Linear(in_features=32, out_features=16, bias=True)
#   (bn7): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (ln7): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#   (dense8): Linear(in_features=16, out_features=8, bias=True)
#   (bn8): BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (ln8): LayerNorm((8,), eps=1e-05, elementwise_affine=True)
#   (dense_x_para): Linear(in_features=16, out_features=8, bias=True)
#   (merge_layer): Linear(in_features=12, out_features=8, bias=True)
#   (bn_merge_layer): BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (ln_merge_layer): LayerNorm((8,), eps=1e-05, elementwise_affine=True)
#   (densef): Linear(in_features=8, out_features=6, bias=True)
#   (qlayer): <Quantum Torch Layer: func=qnode>
#   (softmax): Softmax(dim=1)
# )

# %%
all_preds = []
all_labels = []

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs = inputs.to(device)
        outputs = model(inputs)

        _,  preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(all_labels, all_preds)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False,
            xticklabels=full_dataset.classes,
            yticklabels=full_dataset.classes)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

# %%
torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': opt.state_dict()
        }, PATH + 'epoch_' + str(epoch) + '.pth')
